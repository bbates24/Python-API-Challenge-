# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
cities
# Out:
# ['puerto escondido',
#  'port alfred',
#  'punta arenas',
#  'coahuayana',
#  'kapaa',
#  'baykit',
#  'piney green',
#  'saint-georges',
#  'humaita',
#  'tidore',
#  'alexandria',
#  'longyearbyen',
#  'nortelandia',
#  'ancud',
#  'hobart',
#  'qunduz',
#  'touros',
#  'tuatapere',
#  'jamestown',
#  'taolanaro',
#  'airai',
#  'port elizabeth',
#  'bluff',
#  'avarua',
#  'bilibino',
#  'willowmore',
#  'yellowknife',
#  'zhigansk',
#  'ponta do sol',
#  'cape town',
#  'ushuaia',
#  'albany',
#  'hithadhoo',
#  'ziro',
#  'amderma',
#  'san fernando',
#  'hilo',
#  'leningradskiy',
#  'thornbury',
#  'ternate',
#  'gambiran',
#  'new norfolk',
#  'shahreza',
#  'vao',
#  'sao joao da barra',
#  'vaini',
#  'victoria',
#  'mar del plata',
#  'metro',
#  'utiroa',
#  'ribeira grande',
#  'atuona',
#  'castro',
#  'jaguaribe',
#  'miyoshi',
#  'saldanha',
#  'zhangye',
#  'busselton',
#  'saint-philippe',
#  'constitucion',
#  'palabuhanratu',
#  'yar-sale',
#  'bengkulu',
#  'prestea',
#  'lodwar',
#  'marsh harbour',
#  'barentsburg',
#  'bambous virieux',
#  'zaterechnyy',
#  'ust-kulom',
#  'rikitea',
#  'harper',
#  'oregon city',
#  'belushya guba',
#  'padang',
#  'coihaique',
#  'butaritari',
#  'carmo do rio claro',
#  'illoqqortoormiut',
#  'inuvik',
#  'oeiras',
#  'boyabat',
#  'cayenne',
#  'chuy',
#  'north bend',
#  'kawerau',
#  'bol',
#  'mahebourg',
#  'hay river',
#  'barrow',
#  'porto murtinho',
#  'luderitz',
#  'ghanzi',
#  'lazaro cardenas',
#  'guilin',
#  'hermanus',
#  'carnarvon',
#  'iqaluit',
#  'khandyga',
#  'provideniya',
#  'mataura',
#  'rocha',
#  'severo-kurilsk',
#  'mayskiy',
#  'chabahar',
#  'lagoa',
#  'ternuvate',
#  'nanortalik',
#  'namibe',
#  'nome',
#  'ugoofaaru',
#  'san quintin',
#  'bekhtery',
#  'nouakchott',
#  'severnyy',
#  'verkh-usugli',
#  'redmond',
#  'palu',
#  'isangel',
#  'fortuna',
#  'hatillo',
#  'san antero',
#  'seddon',
#  'katsuura',
#  'port hedland',
#  'thompson',
#  'saleaula',
#  'bedi',
#  'lavrentiya',
#  'cidreira',
#  'masuguru',
#  'saskylakh',
#  'kodiak',
#  'sentyabrskiy',
#  'komsomolskiy',
#  'aksarka',
#  'medea',
#  'pangnirtung',
#  'vata de jos',
#  'college',
#  'puerto ayora',
#  'krasnyy chikoy',
#  'geraldton',
#  'qaanaaq',
#  'port hardy',
#  'gari',
#  'sorvag',
#  'reefton',
#  'tulu bolo',
#  'yasnyy',
#  'jurilovca',
#  'tasiilaq',
#  'port-cartier',
#  'georgetown',
#  'svetlogorsk',
#  'novopokrovka',
#  'yuzhno-yeniseyskiy',
#  'san cristobal',
#  'paamiut',
#  'nantucket',
#  'marawi',
#  'sydney',
#  'kurumkan',
#  'zhangjiakou',
#  'arandis',
#  'lorengau',
#  'esperance',
#  'keffi',
#  'wad rawah',
#  'chokurdakh',
#  'gayny',
#  'tiksi',
#  'praia da vitoria',
#  'aban',
#  'waingapu',
#  'upernavik',
#  'souillac',
#  'beringovskiy',
#  'kahului',
#  'sur',
#  'hasaki',
#  'albanel',
#  'canyon',
#  'kiama',
#  'ambilobe',
#  'cartagena',
#  'naze',
#  'kijang',
#  'blue springs',
#  'mutis',
#  'pekalongan',
#  'armacao dos buzios',
#  'lolua',
#  'pershotravneve',
#  'caravelas',
#  'kavaratti',
#  'quelimane',
#  'goure',
#  'bredasdorp',
#  'alpena',
#  'dharmanagar',
#  'attawapiskat',
#  'rio verde de mato grosso',
#  'rockland',
#  'gigmoto',
#  'alyangula',
#  'dingle',
#  'norman wells',
#  'yambio',
#  'nyurba',
#  'pisco',
#  'nikolskoye',
#  'sao gabriel da cachoeira',
#  'tuktoyaktuk',
#  'pokhara',
#  'nizhneyansk',
#  'bani',
#  'kempsey',
#  'beloha',
#  'visby',
#  'sao filipe',
#  'atar',
#  'vila franca do campo',
#  'hualmay',
#  'clyde river',
#  'cabo san lucas',
#  'iskateley',
#  'balkanabat',
#  'shache',
#  'tumannyy',
#  'sonoita',
#  'bathsheba',
#  'katherine',
#  'nelson bay',
#  'saint george',
#  'kailua',
#  'patamundai',
#  'palana',
#  'kathu',
#  'guerrero negro',
#  'deputatskiy',
#  'walla walla',
#  'kaeo',
#  'nabire',
#  'ust-kuyga',
#  'kattivakkam',
#  'tsihombe',
#  'louisbourg',
#  'bethel',
#  'matara',
#  'waipawa',
#  'tabas',
#  'banda aceh',
#  'havre-saint-pierre',
#  'ostrovnoy',
#  'filadelfia',
#  'egvekinot',
#  'bubaque',
#  'mys shmidta',
#  'yerbogachen',
#  'adrar',
#  'arraial do cabo',
#  'hovd',
#  'iquique',
#  'zaoyang',
#  'colares',
#  'toliary',
#  'flinders',
#  'bilma',
#  'tautira',
#  'kalomo',
#  'ruatoria',
#  'inhambane',
#  'brae',
#  'eirunepe',
#  'boffa',
#  'warqla',
#  'morros',
#  'fairbanks',
#  'ust-maya',
#  'asau',
#  'lukovetskiy',
#  'mitu',
#  'kendari',
#  'sechura',
#  'tigil',
#  'selenginsk',
#  'ayan',
#  'cervo',
#  'khatanga',
#  'yirol',
#  'pecos',
#  'agadez',
#  'porto walter',
#  'leo',
#  'broken hill',
#  'san antonio',
#  'narsaq',
#  'faya',
#  'pevek',
#  'greystones',
#  'barinas',
#  'margate',
#  'coquimbo',
#  'olafsvik',
#  'hamilton',
#  'xining',
#  'lisakovsk',
#  'boddam',
#  'labutta',
#  'mao',
#  'aripuana',
#  'umm kaddadah',
#  'sao luiz gonzaga',
#  'bowling green',
#  'phuket',
#  'saginaw',
#  'saint anthony',
#  'rawson',
#  'barysh',
#  'beruwala',
#  'kandrian',
#  'namatanai',
#  'vaitape',
#  'amalapuram',
#  'samusu',
#  'mananjary',
#  'korla',
#  'makakilo city',
#  'tinskoy',
#  'east london',
#  'san juan del sur',
#  'comodoro rivadavia',
#  'lebu',
#  'oranjemund',
#  'remanso',
#  'klyuchi',
#  'challans',
#  'tabuk',
#  'aklavik',
#  'maragogi',
#  'morant bay',
#  'ixtapa',
#  'changying',
#  'viedma',
#  'los llanos de aridane',
#  'broome',
#  'bonavista',
#  'sioux lookout',
#  'marcona',
#  'malwan',
#  'grindavik',
#  'hobyo',
#  'talnakh',
#  'vostok',
#  'salalah',
#  'sao paulo de olivenca',
#  'cabedelo',
#  'mocambique',
#  'zlitan',
#  'aswan',
#  'sao felix do xingu',
#  'sangar',
#  'simao',
#  'goderich',
#  'lata',
#  'pochutla',
#  'nouadhibou',
#  'greece',
#  'richmond',
#  'cruzeiro do sul',
#  'lahij',
#  'acarau',
#  'vestmannaeyjar',
#  'lasa',
#  'anadyr',
#  'te anau',
#  'cochrane',
#  'torbay',
#  'tucurui',
#  'dikson',
#  'dwarka',
#  'saint-pierre',
#  'nanakuli',
#  'yulara',
#  'port-gentil',
#  'nioro',
#  'zastron',
#  'kuningan',
#  'cubulero',
#  'bloomfield',
#  'waddan',
#  'surt',
#  'puerto del rosario',
#  'bithur',
#  'diffa',
#  'portland',
#  'grand river south east',
#  'christchurch',
#  'bardiyah',
#  'krasnoselkup',
#  'kavieng',
#  'ribas do rio pardo',
#  'murgab',
#  'seoul',
#  'vytegra',
#  'chicama',
#  'rungata',
#  'vulcan',
#  'jiayuguan',
#  'mocuba',
#  'kaihua',
#  'pietersburg',
#  'lixourion',
#  'bukachacha',
#  'sinjah',
#  'lucapa',
#  'plettenberg bay',
#  'chumikan',
#  'scottsburgh',
#  'san andres',
#  'laramie',
#  'gat',
#  'duzce',
#  'ciudad bolivar',
#  'vila',
#  'linqiong',
#  'tiznit',
#  'skjervoy',
#  'lucea',
#  'riyadh',
#  'santa cruz',
#  'praya',
#  'auki',
#  'conceicao do araguaia',
#  'rio gallegos',
#  'porto velho',
#  'gangotri',
#  'mangaratiba',
#  'maragheh',
#  'meyungs',
#  'kpandae',
#  'san matias',
#  'vaitupu',
#  'omboue',
#  'elko',
#  'villarrobledo',
#  'general roca',
#  'mehamn',
#  'chimbote',
#  'turayf',
#  'khakhea',
#  'maniitsoq',
#  'maple creek',
#  'crotone',
#  'cherskiy',
#  'general pico',
#  'aktash',
#  'moron',
#  'tabou',
#  'tecate',
#  'kiunga',
#  'henties bay',
#  'lompoc',
#  'tamale',
#  'bandar-e lengeh',
#  'rostaq',
#  'aksu',
#  'sebinkarahisar',
#  'poronaysk',
#  'barcelos',
#  'kyzyl-suu',
#  'abha',
#  'meulaboh',
#  'gorontalo',
#  'merritt',
#  'pouembout',
#  'havelock',
#  'port lincoln',
#  'huarmey',
#  'finnsnes',
#  'bambanglipuro',
#  'rafai',
#  'linchuan',
#  'virginia beach',
#  'tawkar',
#  'uttaradit',
#  'khani',
#  'boulder city',
#  'ulaanbaatar',
#  'mount gambier',
#  'baglung',
#  'caborca',
#  'tecpan',
#  'manyana',
#  'kirkuk',
#  'tual',
#  'ngukurr',
#  'orje',
#  'almeria',
#  'manggar',
#  'taoudenni',
#  'weston',
#  'kamenskoye',
#  'tombouctou',
#  'fuyang',
#  'fomboni',
#  'pagudpud',
#  'kamaishi',
#  'umzimvubu',
#  'kruisfontein',
#  'san juan',
#  'sitka',
#  'padre bernardo',
#  'cockburn town',
#  'mbarara',
#  'bandarbeyla',
#  'muroto',
#  'ipojuca',
#  'kwakoa',
#  'mayo',
#  'umkomaas',
#  'neustadt',
#  'remontnoye',
#  'inderborskiy',
#  'fort nelson',
#  'shubarshi',
#  'brigantine',
#  'gornopravdinsk',
#  'salta',
#  'bazarnyye mataki',
#  'kango',
#  'piacabucu',
#  'verkhnya syrovatka',
#  'ayaviri',
#  'dunedin',
#  'gatton',
#  'rivers',
#  'bujaru',
#  'awjilah',
#  'palmer',
#  'puerto madero',
#  'yumen',
#  'sri aman',
#  'port blair',
#  'orkney',
#  'vila velha',
#  'mizdah',
#  'fremont',
#  'alofi',
#  'srednekolymsk',
#  'gardenstown',
#  'evensk',
#  'banmo',
#  'inirida',
#  'longlac',
#  'azanka',
#  'avera',
#  'hambantota',
#  'nagorsk',
#  'manzil tamim',
#  'carballo',
#  'crepy-en-valois',
#  'trelew',
#  'arawa',
#  'dongkan',
#  'sabha',
#  'linxia',
#  'dehloran',
#  'baghdad',
#  'sisimiut',
#  'wilhelmshaven',
#  'itoman',
#  'chivay',
#  'neryungri',
#  'oxford',
#  'trairi',
#  'sangueya',
#  'charlestown',
#  'jinchang',
#  'fare',
#  'sao joao dos patos',
#  'sao raimundo nonato',
#  'valdivia',
#  'viligili',
#  'maine-soroa',
#  'kirovskiy',
#  'silver city',
#  'de panne',
#  'moosomin',
#  'cumra',
#  'santa marinella',
#  'genhe']

# %%
import requests

x = requests.get('http://api.openweathermap.org/data/2.5/weather?q=London&appid=9efd0c479c718c66e129d30ac7053e00')

print(x.text)
# Out:
# {"coord":{"lon":-0.13,"lat":51.51},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":272.5,"feels_like":269.18,"temp_min":270.93,"temp_max":274.15,"pressure":1003,"humidity":90},"visibility":10000,"wind":{"speed":1.5,"deg":290},"clouds":{"all":0},"dt":1609381378,"sys":{"type":1,"id":1414,"country":"GB","sunrise":1609401973,"sunset":1609430448},"timezone":0,"id":2643743,"name":"London","cod":200}

# %%
import time

# %%
data=[]
for i,city in enumerate(cities):
    url='http://api.openweathermap.org/data/2.5/weather?q='+city+'&appid=9efd0c479c718c66e129d30ac7053e00'
    x= requests.get(url)
    print(x)
    if x.status_code==200:
        data.append(x.json())
    time.sleep(1)
    if i ==10:
        break
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [404]>
# <Response [200]>

# %%
data
# Out:
# ['{"coord":{"lon":-97.07,"lat":15.85},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"base":"stations","main":{"temp":298.15,"feels_like":301.23,"temp_min":298.15,"temp_max":298.15,"pressure":1011,"humidity":78},"visibility":10000,"wind":{"speed":1.5,"deg":280},"clouds":{"all":75},"dt":1609381723,"sys":{"type":1,"id":7157,"country":"MX","sunrise":1609332900,"sunset":1609373212},"timezone":-21600,"id":3520994,"name":"Puerto Escondido","cod":200}',
#  '{"coord":{"lon":26.89,"lat":-33.59},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"base":"stations","main":{"temp":293.15,"feels_like":295.29,"temp_min":293.15,"temp_max":293.15,"pressure":1011,"humidity":92},"visibility":10000,"wind":{"speed":1.34,"deg":269,"gust":4.02},"clouds":{"all":79},"dt":1609381724,"sys":{"type":3,"id":2011314,"country":"ZA","sunrise":1609383908,"sunset":1609435540},"timezone":7200,"id":964432,"name":"Port Alfred","cod":200}',
#  '{"coord":{"lon":-70.92,"lat":-53.15},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":283.92,"feels_like":279.94,"temp_min":283.71,"temp_max":284.15,"pressure":998,"humidity":76},"visibility":10000,"wind":{"speed":4.6,"deg":360},"clouds":{"all":100},"dt":1609381725,"sys":{"type":1,"id":8487,"country":"CL","sunrise":1609316397,"sunset":1609377159},"timezone":-10800,"id":3874787,"name":"Punta Arenas","cod":200}',
#  '{"coord":{"lon":-103.68,"lat":18.73},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"base":"stations","main":{"temp":293.26,"feels_like":294.64,"temp_min":293.26,"temp_max":293.26,"pressure":1012,"humidity":76,"sea_level":1012,"grnd_level":1010},"visibility":10000,"wind":{"speed":0.73,"deg":284},"clouds":{"all":39},"dt":1609381726,"sys":{"country":"MX","sunrise":1609334810,"sunset":1609374477},"timezone":-21600,"id":4013679,"name":"Coahuayana Viejo","cod":200}',
#  '{"coord":{"lon":-159.32,"lat":22.08},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"stations","main":{"temp":298.9,"feels_like":298.43,"temp_min":298.71,"temp_max":299.15,"pressure":1019,"humidity":69},"visibility":10000,"wind":{"speed":5.7,"deg":40},"clouds":{"all":1},"dt":1609381727,"sys":{"type":1,"id":7873,"country":"US","sunrise":1609348556,"sunset":1609387446},"timezone":-36000,"id":5848280,"name":"Kapaa","cod":200}',
#  '{"coord":{"lon":96.37,"lat":61.67},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":241.57,"feels_like":236.76,"temp_min":241.57,"temp_max":241.57,"pressure":1048,"humidity":79,"sea_level":1048,"grnd_level":1026},"visibility":10000,"wind":{"speed":1.32,"deg":66},"clouds":{"all":0},"dt":1609381729,"sys":{"country":"RU","sunrise":1609383260,"sunset":1609402827},"timezone":25200,"id":1510689,"name":"Baykit","cod":200}',
#  '{"coord":{"lon":-77.32,"lat":34.72},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":287.19,"feels_like":284.73,"temp_min":285.93,"temp_max":288.15,"pressure":1024,"humidity":77},"visibility":10000,"wind":{"speed":3.6,"deg":170},"clouds":{"all":1},"dt":1609381730,"sys":{"type":1,"id":5060,"country":"US","sunrise":1609330570,"sunset":1609366059},"timezone":-18000,"id":4485355,"name":"Piney Green","cod":200}',
#  '{"coord":{"lon":-61.75,"lat":12.06},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"base":"stations","main":{"temp":298.15,"feels_like":300.14,"temp_min":298.15,"temp_max":298.15,"pressure":1013,"humidity":83},"visibility":10000,"wind":{"speed":3.8,"deg":38},"clouds":{"all":75},"dt":1609381731,"sys":{"type":1,"id":8781,"country":"GD","sunrise":1609324011,"sunset":1609365143},"timezone":-14400,"id":3579925,"name":"St. George\'s","cod":200}',
#  '{"coord":{"lon":-63.02,"lat":-7.51},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":296.62,"feels_like":300.7,"temp_min":296.62,"temp_max":296.62,"pressure":1010,"humidity":92,"sea_level":1010,"grnd_level":1005},"visibility":10000,"wind":{"speed":0.96,"deg":62},"clouds":{"all":100},"dt":1609381732,"sys":{"country":"BR","sunrise":1609322288,"sunset":1609367475},"timezone":-14400,"id":3664078,"name":"Humaitá","cod":200}',
#  '{"coord":{"lon":29.96,"lat":31.22},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"base":"stations","main":{"temp":287.15,"feels_like":287.19,"temp_min":287.15,"temp_max":287.15,"pressure":1017,"humidity":87},"visibility":6000,"wind":{"speed":0.77,"deg":74},"clouds":{"all":40},"dt":1609381477,"sys":{"type":1,"id":2511,"country":"EG","sunrise":1609390716,"sunset":1609427258},"timezone":7200,"id":361058,"name":"Alexandria","cod":200}']

# %%
x=data[0]
x['coord']
x['coord']['lon']
x['weather']
x['weather'][0]
x['weather'][0]['main']
# Out:
# 'Clouds'
